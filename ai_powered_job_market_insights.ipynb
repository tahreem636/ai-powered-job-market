# %% [markdown]
# <a href="https://colab.research.google.com/github/tahreem636/ai-powered-job-market/blob/main/ai_powered_job_market_insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/CONTENT/'

# %%
# !kaggle datasets download -d uom190346a/ai-powered-job-market-insights
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uom190346a/ai-powered-job-market-insights
# License(s): CC0-1.0
# ...
#   0% 0.00/10.4k [00:00<?, ?B/s]
# 100% 10.4k/10.4k [00:00<00:00, 17.5MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/ai-powered-job-market-insights.zip')
df
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# ...

# %%
# !kaggle datasets download -d prokshitha/ai-powered-job-market-insights
# Out:
# 403 - Forbidden - Permission 'datasets.get' was denied

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  ai-powered-job-market-insights.zip
#   inflating: ai_job_market_insights.csv

# %%
df1=pd.read_csv('ai_job_market_insights.csv')
df1.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Large  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.165243
# 1            Medium            High           Marketing   93792.562466
# 2            Medium            High        UX/UI Design  107170.263069
# 3               Low            High  Project Management   93027.953758
# 4               Low             Low          JavaScript   87752.922171
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# ...
